# %%
from ipywidgets import interact, interactive, fixed
import matplotlib.pyplot as plt

# %%
import ipywidgets as widgets

# %%
def f(x):
    return x**2

# %%
y = interact(f, x=widgets.IntSlider(min=10, max=30, step=1, value=10))
# Out:
# interactive(children=(IntSlider(value=10, description='x', max=30, min=10), Output()), _dom_classes=('widget-i…

# %%
w = widgets.IntSlider(min=10, max=40, step=1,value=10)

# %%
display(w)
# Out:
# IntSlider(value=18, max=40, min=10)

# %%
def on_change(name,value):
    print(value)

# %%
w.observe(handler=on_change,type='change')

# %%
from ipywidgets import interactive
from IPython.display import Audio, display
import numpy as np

def beat_freq(f1=220.0, f2=224.0):
    max_time = 3
    rate = 8000
    times = np.linspace(0,max_time,rate*max_time)
    signal = np.sin(2*np.pi*f1*times) + np.sin(2*np.pi*f2*times)
    display(Audio(data=signal, rate=rate))
    return signal

v = interactive(beat_freq, f1=(200.0,300.0), f2=(200.0,300.0))
display(v)
f1, f2 = v.children[:2]
f1.value = 255
f2.value = 260
plt.plot(v.result[0:6000]);
# Out:
# interactive(children=(FloatSlider(value=220.0, description='f1', max=300.0, min=200.0), FloatSlider(value=224.…

# %%
plt.plot(v.result[0:6000]);
